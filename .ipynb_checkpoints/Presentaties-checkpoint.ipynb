# %% [markdown]
# Presentation Hackathon Den Bosch:

# %% [markdown]
# * Probleem
# * Ideale toekomst
# * Analyse (plaatje met variabelen)
#     * Overzicht --> inzoomen op elke variabele
#     * Q: % dat mensen niet thuis zijn --> thuis/ niet thuis verhouding
#     * temperatuur wanneer water stil staat --> na 2 dagen

# %%
from IPython.display import Image
Image(filename='analysis.png')

# %% [markdown]
# 1. verschillen in locaties
#     * Noorderkroon
#     * Nieuwehagen

# %% [markdown]
# 2. Tapping point

# %% [markdown]
# 3. Wel/ niet thuis

# %% [markdown]
# 4. Legionella & T

# %% [markdown]
# 5. Time analysis Legionella

# %%
import os

# %%
__File__FILE
# Out:
# '.'
