# %%
import pandas as pd
import numpy as np
from jupyterthemes import jtplot
import matplotlib.pyplot as plt
jtplot.style()

df = pd.read_csv('../data/Temperatuur_Flow.csv')
df['uitleestijdstip'] = pd.to_datetime(df['uitleestijdstip'])
df = df.sort_values(['v-app','uitleestijdstip'])
df.set_index('uitleestijdstip', inplace=True)
df['vol'] = df['volume 1']
df['target'] = df['delta (omg-med)']
df['inx'] = df['Unnamed: 0']

# %%
df['gelogde gemiddelde omgevingstemp.'].groupby(df.ligging).describe()
# Out:
#            count       mean       std   min   25%   50%   75%   max
# ligging
# schaduw  63033.0  21.354291  3.118350  11.0  20.0  22.0  24.0  28.0
# zon      94376.0  21.337045  2.527295  13.0  20.0  22.0  23.0  27.0

# %%
dfs = df[df.ligging == 'schaduw']
dfz = df[df.ligging == 'zon']

dfs['gelogde gemiddelde omgevingstemp.'].groupby(dfs.index.date).max().plot()
dfz['gelogde gemiddelde omgevingstemp.'].groupby(dfz.index.date).max().plot()

# %%
dfs['gelogde gemiddelde omgevingstemp.'].groupby(dfs.index.date).mean().plot()
dfz['gelogde gemiddelde omgevingstemp.'].groupby(dfz.index.date).mean().plot()
