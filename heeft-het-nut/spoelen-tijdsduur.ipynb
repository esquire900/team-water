# %%
import pandas as pd
import numpy as np
from jupyterthemes import jtplot
import matplotlib.pyplot as plt
plt.style.use('bmh')

jtplot.style()

import statsmodels.api as sm

# %%
df = pd.read_csv('../data/Beheerdersplan_Spoelen archief.csv')

# %%
df.groupby('kritisch punt (onderwerp)').count()
# Out:
#                                                     locatienaam  datum  \
# kritisch punt (onderwerp)
#  Douchemengkraan + wastafelmengkraan                         35     35
#  Wastafelmengkraan                                           35     35
#  keukenmengkraan                                            105    105
#  wasmachinekraan                                             35     35
# Alle koud water tappunten                                    36     36
# Alle warm water tappunten                                    36     36
# Douchemengkraan + wastafelmengkraan                          35     35
# Indien aan de orde: Koudwatertappunten in appar...           92     92
# Indien aan de orde: Warmwatertappunten in appar...           92     92
# Mengkraan boven spoelbak                                     70     70
# Ruimte A.0.57 alle aanwezige tappunten                       35     35
# Ruimte A0.56 alle aanwezige tappunten                        35     35
# ...

# %%
df
# Out:
#             locatienaam       datum          frequentie  \
# 0      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 1      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 2      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 3      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 4      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 5      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 6      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 7      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 8      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 9      Nieuwehagen (HW)  2016-06-06           Wekelijks
# 10     Nieuwehagen (HW)  2016-06-06           Wekelijks
# 11     Nieuwehagen (HW)  2016-07-04           Wekelijks
# 12     Nieuwehagen (HW)  2016-07-04           Wekelijks
# 13     Nieuwehagen (HW)  2016-07-04           Wekelijks
# 14     Nieuwehagen (HW)  2016-07-04           Wekelijks
# 15     Nieuwehagen (HW)  2016-07-04           Wekelijks
# ...
